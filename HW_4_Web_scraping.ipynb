# %% [markdown]
# # WH_4 - Web scraping

# %% [markdown]
# ## importing ibraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %% [markdown]
# ## scraping function

# %%
def scrape_madlan(city): #Between the words, use a hyphen. For example ('כפר-סבא')
    
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.63 Safari/537.36'}
    url = "https://www.madlan.co.il/for-sale/" + city + "-ישראל"
    response = requests.get(url,headers= headers)
    
    try:
        if not response.status_code == 200:
            print("You have a problem with the request for madlan's home page - status_code:", response.status_code)
            return None
    
        results_page_assets = BeautifulSoup(response.content, 'html.parser')

        # An empty list to store asset details
        assets_results = list()

        # Find all assets on the page
        assets_lst = results_page_assets.find_all('div',{'class':"css-zuyt5t e1sx3tzs1",'data-auto': "listed-bulletin",'data-auto-bulletin-type':"bulletin"})

        city = results_page_assets.find('div' ,{'class':'css-7so23d e3vrfmg6','data-auto':"breadcrumb-text"}).text
        # loop over each asset and extract the details
        for asset in assets_lst:
            asset_details = {}
            asset_property_class = asset.find('div', {'data-auto': 'property-class'})
            asset_details['City'] = city
            asset_details['type'] = asset_property_class.get_text() if asset_property_class is not None else None

            asset_room_number = asset.find("div", {"data-auto": "property-rooms"})
            asset_room_number_string = asset_room_number.text.strip() if asset_room_number else None
            asset_details['room_number'] = str(re.sub(r'[^\d.-]', '', asset_room_number_string) if asset_room_number_string else None)

            asset_area = asset.find("div", {"data-auto": "property-size"})
            asset_area_string = asset_area.text.strip() if asset_area else "None"
            asset_area_numbers_only = re.findall(r'\d+', asset_area_string)
            asset_details['Area'] = int(asset_area_numbers_only[0]) if asset_area_numbers_only else None

            asset_address = asset.find('div', {'data-auto': 'property-address'})
            asset_address = asset_address.get_text(strip=True) if asset_address else "None"
            Street_and_num = asset_address.split(',')[0] if asset_address != "None" else "None"
            Street_and_num = Street_and_num.split()
            Street = ''
            num = ''
            for part in Street_and_num:
                if part.isnumeric():
                    num = num + part
                else:
                    Street = Street + ' ' + part
            asset_details['Street'] = str(Street.strip()) if Street != '' else None
            asset_details['number_in_street'] = float(num) if num != '' else None
            asset_details['city_area'] = str(asset_address.split(',')[1].strip() if len(asset_address.split(',')) > 1 else None)

            price_element = asset.find("div", {"data-auto": "property-price"})
            price_string = price_element.text.strip() if price_element else "None"
            num_match = re.search(r'\d+(?:,\d+)*', price_string)
            asset_details['price'] = int(num_match.group().replace(',', '')) if num_match else None

            ############################# Bonus #################################################### 

            asset_url = "https://www.madlan.co.il" + asset.find('a').get('href')
            response_asset = requests.get(asset_url,headers= headers)
            results_page_current_asset = BeautifulSoup(response_asset.content,'html.parser')
            photos = results_page_current_asset.find_all('div',{'class': 'css-18nlt6 e1r3dysu3'})
            asset_details['num_of_images'] = len(photos)
            asset_details['floor_out_of'] = results_page_current_asset.find('div', {'data-auto': 'floor'}).get_text() if results_page_current_asset.find('div', {'data-auto': 'floor'}) is not None else None
            blocks_lst = results_page_current_asset.find_all('div',{'class':'css-1wpv10e e125ttrt3'})
            title_names = ['hasElevator','hasAirCondition','hasParking','hasBalcony','hasBars','hasMamad','hasStorage','handicapFriendly']
            for block in range (len(blocks_lst)-1):
                asset_details[title_names[block]] = blocks_lst[block].get_text()

            asset_condition = results_page_current_asset.find("div", {"data-auto": "unit-general-condition-value"})
            asset_details['condition'] = str(asset_condition.get_text() if asset_condition  is not None else None)

            asset_entranceDate = results_page_current_asset.find("div", {"data-auto": "unit-availability-value"})
            asset_details['entranceDate'] = str(asset_entranceDate.text.strip() if asset_entranceDate  is not None else None)

            asset_furniture = results_page_current_asset.find("div", {"data-auto": "unit-furniture-details-value"})
            asset_details['furniture'] = str(asset_furniture.text.strip() if asset_furniture  is not None else None)

            asset_details['publishedDays'] = None # Change in the assignment according to the lecturer to leave the column empty unless it is filled in manually

            asset_description = results_page_current_asset.find("div", {"class": "css-v1qjdi ebqee3y2"})
            asset_details['description'] = str(asset_description.text.strip() if asset_description  is not None else None)

            ############################# Bonus #################################################### 

            # Append asset details to the assets_results
            assets_results.append(asset_details)
        
    except:
        pass
    
    return assets_results

# %%
assets_details = pd.DataFrame(scrape_madlan('כפר-סבא'))

# %% [markdown]
# ## The arrangement of the data frame

# %%
assets_details_save_copy = assets_details # Just in case
order_columns = ['City','type', 'room_number','Area', 'Street', 'number_in_street', 'city_area', 'price', 'num_of_images', 'floor_out_of',
                 'hasElevator', 'hasParking', 'hasBars', 'hasStorage', 'condition', 'hasAirCondition', 'hasBalcony', 'hasMamad',
                 'handicapFriendly','entranceDate', 'furniture','publishedDays', 'description']
assets_details = assets_details[order_columns]
columns_to_fillna = ['hasElevator', 'hasParking', 'hasBars', 'hasStorage', 'hasAirCondition', 'hasBalcony', 'hasMamad',
                 'handicapFriendly']
assets_details[columns_to_fillna] = assets_details[columns_to_fillna].fillna('False')

# %%
assets_details
# Out:
#        City       type room_number   Area                      Street  \
# 0   כפר סבא       דירה           4  122.0                      ביאליק
# 1   כפר סבא       דירה           3   85.0                       הגר"א
# 2   כפר סבא       דירה         3.5    NaN                       נחשון
# 3   כפר סבא     דופלקס         5.5    NaN                   ארלוזורוב
# 4   כפר סבא       דירה           4  125.0                       ויצמן
# 5   כפר סבא       דירה           5  132.0                       נלקין
# 6   כפר סבא       דירה           3    NaN  מוצקין/דובדבן הכפר/כיסופים
# 7   כפר סבא       דירה         3.5   84.0                        יבנה
# 8   כפר סבא       דירה           4  110.0                        הרצל
# 9   כפר סבא       דירה           5  143.0                     רוטשילד
# 10  כפר סבא    דירת גן           4  106.0               השכונה הירוקה
# 11  כפר סבא       דירה           3  106.0                         ברק
# 12  כפר סבא       דירה           4  143.0                   מנור אהוד
# 13  כפר סבא       דירה           5  130.0                     סוקולוב
# 14  כפר סבא       דירה           3  106.0                   חצרות הדר
# 15  כפר סבא    דירת גן           5  129.0               השכונה הירוקה
# 16  כפר סבא       דירה           6  161.0                   מנור אהוד
# 17  כפר סבא       דירה           4  100.0         דובה ויצחק שיינפיין
# 18  כפר סבא  דו משפחתי           9  314.0                       הפארק
# 19  כפר סבא       דירה           6  137.0                        אז"ר
# 20  כפר סבא       דירה           4  143.0                    זהבי דוד
# 21  כפר סבא       דירה           4  123.0                       נחשון
# 22  כפר סבא     דופלקס           6  191.0                 משעול האהבה
# 23  כפר סבא       דירה           4  100.0                       הדרים
# 24  כפר סבא    דירת גג           4  150.0                   ארלוזורוב
# 25  כפר סבא       דירה           4  100.0                   ארגוב סשה
# 26  כפר סבא       דירה           4  131.0                       ויצמן
# 27  כפר סבא  דו משפחתי         3.5  100.0                      אלישבע
# 28  כפר סבא    פנטהאוז           4  135.0                   ארלוזורוב
# 29  כפר סבא    דירת גג           7  168.0                       השפלה
# 30  כפר סבא       דירה           5  136.0                        העמק
# 31  כפר סבא  דו משפחתי           5  150.0                       הדרים
# 32  כפר סבא       דירה         5.5  138.0                   אהרונוביץ
# 33  כפר סבא       דירה           4  113.0                    שמר נעמי
#
#     number_in_street                   city_area    price  num_of_images  \
# 0               22.0              מרכז העיר דרום  3100000             11
# 1                6.0              מרכז העיר דרום  2850000              6
# 2                NaN              מרכז העיר דרום  2300000              2
# 3                NaN              מרכז העיר דרום  4100000              1
# 4               78.0              מרכז העיר דרום   777777              5
# 5                2.0               השכונה הירוקה  4200000              0
# 6                NaN                        None  2400000              1
# 7                NaN  מוצקין/דובדבן הכפר/כיסופים  2490000              7
# 8               26.0              מרכז העיר דרום  2890000              6
# 9               16.0              מרכז העיר דרום  3450000             13
# 10               NaN                        None  4400000              8
# 11               NaN                     אלי כהן  2890000              3
# 12               8.0                  הזמר העברי  3650000              0
# 13              12.0              מרכז העיר דרום  3900000              0
# 14               NaN                        None  2890000              0
# 15               NaN                        None   530000              0
# 16               2.0                  הזמר העברי  4850000              0
# 17               8.0               השכונה הירוקה  3850000              0
# 18               NaN                        None  8750000              0
# 19               NaN  מוצקין/דובדבן הכפר/כיסופים  4340000              0
# 20              16.0                  הזמר העברי  3650000              0
# 21              11.0              מרכז העיר דרום  3190000              0
# 22               NaN                       תקומה  5900000              0
# 23               NaN                        None  2950000              0
# 24              23.0              מרכז העיר דרום  3950000              0
# 25               7.0                  הזמר העברי  3600000              0
# 26               NaN                 פרחים/דגניה  2750000              0
# 27               NaN              למפרט/פועלים ב  5430000              0
# 28              23.0              מרכז העיר דרום  3850000              0
# 29               4.0  מוצקין/דובדבן הכפר/כיסופים  5700000              0
# 30              14.0                       תקומה  3470000              0
# 31               NaN                        None  5480000              0
# 32              15.0              מרכז העיר דרום  3850000              0
# 33               4.0                  הזמר העברי  3700000              0
#
#      floor_out_of  ... hasStorage condition hasAirCondition hasBalcony  \
# 0   קומה 1 מתוך 4  ...   אין מחסן      שמור   יש מיזוג אויר   יש מרפסת
# 1   קומה 2 מתוך 3  ...   אין מחסן     משופץ   יש מיזוג אויר  אין מרפסת
# 2   קומה 1 מתוך 5  ...   אין מחסן      שמור   יש מיזוג אויר  אין מרפסת
# 3   קומה 5 מתוך 6  ...   אין מחסן       ישן   יש מיזוג אויר   יש מרפסת
# 4          קומה 3  ...   אין מחסן     משופץ   יש מיזוג אויר  אין מרפסת
# 5       קומת קרקע  ...    יש מחסן       חדש   יש מיזוג אויר  אין מרפסת
# 6   קומה 2 מתוך 4  ...   אין מחסן       חדש   יש מיזוג אויר   יש מרפסת
# 7   קומה 4 מתוך 6  ...   אין מחסן       חדש   יש מיזוג אויר   יש מרפסת
# 8   קומה 2 מתוך 5  ...   אין מחסן     משופץ   יש מיזוג אויר  אין מרפסת
# 9   קומה 2 מתוך 4  ...   אין מחסן     משופץ   יש מיזוג אויר  אין מרפסת
# 10      קומת קרקע  ...    יש מחסן       חדש   יש מיזוג אויר   יש מרפסת
# 11  קומה 4 מתוך 5  ...    יש מחסן      שמור   יש מיזוג אויר   יש מרפסת
# 12  קומה 2 מתוך 6  ...    יש מחסן      שמור   יש מיזוג אויר  אין מרפסת
# 13  קומה 5 מתוך 6  ...   אין מחסן       חדש   יש מיזוג אויר  אין מרפסת
# 14           None  ...      False      None           False      False
# 15           None  ...      False      None           False      False
# 16           None  ...      False      None           False      False
# 17           None  ...      False      None           False      False
# 18           None  ...      False      None           False      False
# 19           None  ...      False      None           False      False
# 20           None  ...      False      None           False      False
# 21           None  ...      False      None           False      False
# 22           None  ...      False      None           False      False
# 23           None  ...      False      None           False      False
# 24           None  ...      False      None           False      False
# 25           None  ...      False      None           False      False
# 26           None  ...      False      None           False      False
# 27           None  ...      False      None           False      False
# 28           None  ...      False      None           False      False
# 29           None  ...      False      None           False      False
# 30           None  ...      False      None           False      False
# 31           None  ...      False      None           False      False
# 32           None  ...      False      None           False      False
# 33           None  ...      False      None           False      False
#
#     hasMamad handicapFriendly entranceDate  \
# 0    יש ממ״ד    לא נגיש לנכים      12/2023
# 1   אין ממ״ד    לא נגיש לנכים      08/2023
# 2   אין ממ״ד       נגיש לנכים         גמיש
# 3   אין ממ״ד    לא נגיש לנכים         גמיש
# 4   אין ממ״ד       נגיש לנכים        מיידי
# 5    יש ממ״ד       נגיש לנכים     לא צויין
# 6    יש ממ״ד    לא נגיש לנכים     לא צויין
# 7    יש ממ״ד       נגיש לנכים         גמיש
# 8   אין ממ״ד    לא נגיש לנכים         גמיש
# 9   אין ממ״ד    לא נגיש לנכים      10/2023
# 10   יש ממ״ד       נגיש לנכים         גמיש
# 11   יש ממ״ד       נגיש לנכים        מיידי
# 12   יש ממ״ד    לא נגיש לנכים     לא צויין
# 13   יש ממ״ד       נגיש לנכים     לא צויין
# 14     False            False         None
# 15     False            False         None
# 16     False            False         None
# 17     False            False         None
# 18     False            False         None
# 19     False            False         None
# 20     False            False         None
# 21     False            False         None
# 22     False            False         None
# 23     False            False         None
# 24     False            False         None
# 25     False            False         None
# 26     False            False         None
# 27     False            False         None
# 28     False            False         None
# 29     False            False         None
# 30     False            False         None
# 31     False            False         None
# 32     False            False         None
# 33     False            False         None
#
#                                             furniture publishedDays  \
# 0                                                חלקי          None
# 1                                                 מלא          None
# 2                                            לא צויין          None
# 3                                            לא צויין          None
# 4                                            לא צויין          None
# 5                                            לא צויין          None
# 6                                            לא צויין          None
# 7                                            לא צויין          None
# 8                                            לא צויין          None
# 9                                                 מלא          None
# 10                                           לא צויין          None
# 11                                           לא צויין          None
# 12                                           לא צויין          None
# 13  ארון טלויזיה זכוכית ענק חדר הורים.2 ארונות חדר...          None
# 14                                               None          None
# 15                                               None          None
# 16                                               None          None
# 17                                               None          None
# 18                                               None          None
# 19                                               None          None
# 20                                               None          None
# 21                                               None          None
# 22                                               None          None
# 23                                               None          None
# 24                                               None          None
# 25                                               None          None
# 26                                               None          None
# 27                                               None          None
# 28                                               None          None
# 29                                               None          None
# 30                                               None          None
# 31                                               None          None
# 32                                               None          None
# 33                                               None          None
#
#                                           description
# 0   דירת 4 חדרים, 122 מ״ר לפי ארנונה, קומה ראשונה ...
# 1   דירת 3 חדרים. מיקום מעולה, שקט ומרכזי, קרוב לת...
# 2                                                None
# 3   למכירה במרכז העיר קרוב להכל דופלקס מעולה שייך ...
# 4                            לפני פינוי בינוי עתידי .
# 5   דירה 5 חדרים צופה על גינת נלקין המרכזית בשכונה...
# 6   מציאה של ממש דירה עם חניה, ממד \nברחוב מבוקש ב...
# 7                       דירה חדשה בבניין שעבר תמ"א 38
# 8   ללא תיווך דירה מעוצבת ושמורה מאוד, מזגן בכל חד...
# 9   https://dira.internetido.com/\nלמכירה (ללא תיו...
# 10  חדש בשוק ! למכירה בבלעדיות, דירת גן 4 חד הכי י...
# 11  דירת 3 חד במרכז המבוקש של העיר. בקרבת רכבת, פא...
# 12  * מפרטי* דירת 4 חדרים במצב מצויין בשכונת הזמר ...
# 13  דירה חדשה מקבלן (בת 3), מושקעת ויפיפייה במיקום...
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
#
# [34 rows x 23 columns]

# %% [markdown]
# ## Export to CSV

# %%
assets_details.to_csv('C:\\Users\\Student\\assets_details.csv', encoding='utf-8-sig', index=False)
